# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.set(style='darkgrid')

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # relation plot
# ##  relation plot have scatter and line plot

# %%
sns.relplot(x='total_bill', y='tip', data=df)

# %%
sns.relplot(x='total_bill', y ='tip',data=df, hue='smoker', style='time')

# %%
## use to count the value....

df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip',data=df, size='size')

# %%
sns.relplot(x='total_bill', y='tip',data=df, hue='size')

# %%
sns.relplot(x='total_bill', y='tip',data=df, style='size')

# %%
sns.relplot(x='total_bill', y='tip',data=df, size='size', sizes=(15,200))

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line')

# %%
sns.relplot()

# %%
plt.scatter(df['total_bill'], df['tip'])

# %%
plt.bar(df['size'], df['tip'])
# Out:
# <BarContainer object of 244 artists>

# %%
sns.relplot(x='total_bill', y = 'tip', data = df, hue='smoker', col='time')

# %%
sns.relplot(x='total_bill', y='tip',hue='sex', col='day', data=df)

# %%
sns.relplot(x='total_bill', y='tip',hue='sex', col='day', col_wrap=2, height=3, data=df)

# %%
sns.scatterplot(x='total_bill', y= 'tip', data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x='total_bill', y= 'tip', data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fmri = sns.load_dataset('fmri')
fmri.head(5)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri['event'].value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
sns.lineplot(x='timepoint', y = 'signal',style='region', hue ='event',data=fmri, markers=True)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint', y = 'signal',style='region', hue ='event',data=fmri, markers=True, ci=None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='total_bill', data=df)

# %%
sns.catplot(x='day', y='total_bill', data=df, jitter=False)

# %%
sns.catplot(x='day', y='total_bill', data=df, kind = 'swarm')
