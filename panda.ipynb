# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # rename column name

# %%
df = df.rename(columns={'Type 2': 'Type_2', 'Type 1': 'Type_1'})

# %% [markdown]
# # Creating my own dataframe

# %%
data = {'day':[1,2,3,4,5,6], 'visitor':[1000,700, 1300, 4000, 300, 1500], 'bounce_rate':[20, 20, 30, 10, 23, 25]}
dx = pd.DataFrame(data)
dx.head(2)
dx.tail(2)
# Out:
#    day  visitor  bounce_rate
# 4    5      300           23
# 5    6     1500           25

# %%
# read headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type_1', 'Type_2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## read each column
#print(df['Name'])

## reading 3 column and first 5 data
#print(df[['Name', 'Type 1', 'Type 2']][0:5])

## reading each row
#print(df.iloc[0:4])

## reading a specific location (row, column)
#print(df.iloc[2,1])

# %%
                                          ## Sorting and Describing Data

# %%
## using to describe data 
#df.describe()

## sort the values
#df.sort_values('Name') #ascending order
#df.sort_values('Name' , ascending = False) #decensending order
#df.sort_values(['Type 1', 'HP'], ascending = [1,0]) #decensending order

# %%
df.iloc[520:521] # caling 520 number column
# Out:
#        #     Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 520  469  Yanmega    Bug  Flying  86      76       86      116       56
#
#      Speed  Generation  Legendary
# 520     95           4      False

# %%
                                            ## Changing the data

# %%
## adding extra column 'total'
df['total'] = df['HP'] + df['Attack'] + df['Defense']
df.head(4)
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary  total
# 0       65     45           1      False    143
# 1       80     60           1      False    185
# 2      100     80           1      False    245
# 3      120     80           1      False    303

# %%
## adding column at any place
#df.insert(5,'owner','rakib')
#df

# %%
                                     ## Saving my updated data
#df.to_csv('new_add_column.csv', index = False) # no index
#df.to_excel('new_file.xlcx') #saving excel format data

# %%
## delating a column
df = df.drop(columns=['total'])
df = df.drop(columns=['owner'])
df.head(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c328f6a45974> in <module>
#       1 ## delating a column
#       2 df = df.drop(columns=['total'])
# ----> 3 df = df.drop(columns=['owner'])
#       4 df.head(4)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
## delating a column by index
#df = df.drop(labels=[2], axis=0)
#df

# %%
                                        ##Filtering Data

# %%
## searching all "Type 1" Grass data
df.loc[df['Type_1'] == "Grass"]
# Out:
#        #                   Name Type_1    Type_2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
## searching data 
df.loc[df["HP"] > 150]
# Out:
#        #       Name   Type_1 Type_2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 155  143    Snorlax   Normal    NaN  160     110       65       65      110
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 155     30           1      False
# 217     33           2      False
# 261     55           2      False
# 351     60           3      False
# 655     65           5      False

# %%
## searching data
df.loc[(df['Type_1'] == "Grass") & (df['Type_2'] == 'Poison') & (df['HP'] > 45)]
# Out:
#        #                   Name Type_1  Type_2   HP  Attack  Defense  Sp. Atk  \
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# 452  407               Roserade  Grass  Poison   60      70       65      125
# 651  590                Foongus  Grass  Poison   69      55       45       55
# ...

# %%
                             ## saving new data and changing index

# %%
new_data = df.loc[df['HP'] > 150]
new_data
# Out:
#        #       Name   Type_1 Type_2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 155  143    Snorlax   Normal    NaN  160     110       65       65      110
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 155     30           1      False
# 217     33           2      False
# 261     55           2      False
# 351     60           3      False
# 655     65           5      False

# %%
## setting new data index
new_data =new_data.reset_index(drop=True)
new_data
# Out:
#      #       Name   Type_1 Type_2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  113    Chansey   Normal    NaN  250       5        5       35      105
# 1  143    Snorlax   Normal    NaN  160     110       65       65      110
# 2  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 3  242    Blissey   Normal    NaN  255      10       10       75      135
# 4  321    Wailord    Water    NaN  170      90       45       90       45
# 5  594  Alomomola    Water    NaN  165      75       80       40       45
#
#    Speed  Generation  Legendary
# 0     50           1      False
# 1     30           1      False
# 2     33           2      False
# 3     55           2      False
# 4     60           3      False
# 5     65           5      False

# %%
## saving new data
new_data.to_csv('new_data.csv')

# %%
df.head(6)
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
## searching by using sort string 
#df.loc[df['Name'].str.contains('Mega')] # name data that contains Mega word
df.loc[~df['Name'].str.contains('Mega')] # name data that not contains Mega word
# Out:
#        #                 Name   Type_1  Type_2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
import re
df.loc[df['Type_1'].str.contains('grass|fire', flags=re.I, regex=True)] ## ignoring letter case by using 'flag=re.I'
# Out:
#        #                   Name Type_1  Type_2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
## searching by using only first two letter
df.loc[df["Name"].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type_1    Type_2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
## searching by using only two letter
df.loc[df["Name"].str.contains('pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                     Name    Type_1    Type_2   HP  Attack  Defense  \
# 13    10                 Caterpie       Bug       NaN   45      30       35
# 20    16                   Pidgey    Normal    Flying   40      45       40
# 21    17                Pidgeotto    Normal    Flying   63      60       55
# 22    18                  Pidgeot    Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 42    37                   Vulpix      Fire       NaN   38      41       40
# 76    70               Weepinbell     Grass    Poison   65      90       50
# 84    78                 Rapidash      Fire       NaN   65     100       70
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
                                   ## data value changes

# %%
df.loc[df['Type_1'] == "Fire", 'Type_1'] = 'Flamer' #change fire to flamer
df
# Out:
#        #                   Name   Type_1  Type_2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Type_1'] == "Flamer", 'Type_1'] = 'Fier' #change flamer to fire
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fier     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fier   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
## if hp > 60 then generation value will be 5
df.loc[df["HP"] > 60, ['Generation']] = '5'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fier     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fier   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation  Legendary
# 0         65       65     45          1      False
# ...

# %%
                                         ## stateistics

# %%
## creating mean value of all data 
df.groupby(df["Type_1"]).mean().sort_values('Defense', ascending = False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
## creating sum value of all data 
df.groupby(df["Type_1"]).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type_1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fier      17025  3635    4408     3524     4627     3755   3871         167
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %%
## creating count value of all data 
df.groupby(df["Type_1"]).count()
# Out:
#             #  Name  Type_2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type_1
# Bug        69    69      69   69      69       69       69       69     69
# Dark       31    31      31   31      31       31       31       31     31
# Dragon     32    32      32   32      32       32       32       32     32
# Electric   44    44      44   44      44       44       44       44     44
# Fairy      17    17      17   17      17       17       17       17     17
# Fier       52    52      52   52      52       52       52       52     52
# Fighting   27    27      27   27      27       27       27       27     27
# Flying      4     4       4    4       4        4        4        4      4
# Ghost      32    32      32   32      32       32       32       32     32
# Grass      70    70      70   70      70       70       70       70     70
# Ground     32    32      32   32      32       32       32       32     32
# ...

# %%
df['owner'] = 'abdur'
df.head(5)
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  poison  45      49       49       65
# 1  2                Ivysaur  Grass  poison  60      62       63       80
# 2  3               Venusaur  Grass  poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  poison  80     100      123      122
# 4  4             Charmander   Fier  poison  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  owner
# 0       65     45           1      False  abdur
# 1       80     60           1      False  abdur
# 2      100     80           1      False  abdur
# 3      120     80           1      False  abdur
# 4       50     65           1      False  abdur

# %%
a = [1,2,3]
b = pd.Series(a)
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# # Deleting column and restore it

# %%
cols = df.columns
a = df.pop('Type 1')
a
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fier
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fier
# Name: Type 1, Length: 800, dtype: object

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass     NaN  45      49       49       65
# 1  2                Ivysaur  Grass     NaN  60      62       63       80
# 2  3               Venusaur  Grass     NaN  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass     NaN  80     100      123      122
# 4  4             Charmander   Fier     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  owner
# 0       65     45           1      False    NaN
# 1       80     60           1      False    NaN
# 2      100     80           1      False    NaN
# 3      120     80           1      False    NaN
# 4       50     65           1      False    NaN

# %%
df = df.join(a).reindex(columns = cols) ## this will join the data in last column
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass     NaN  45      49       49       65
# 1  2                Ivysaur  Grass     NaN  60      62       63       80
# 2  3               Venusaur  Grass     NaN  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass     NaN  80     100      123      122
# 4  4             Charmander   Fier     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  owner
# 0       65     45           1      False    NaN
# 1       80     60           1      False    NaN
# 2      100     80           1      False    NaN
# 3      120     80           1      False    NaN
# 4       50     65           1      False    NaN

# %% [markdown]
# # adding Nan value of data

# %% [markdown]
# # # rename column name

# %%
df = df.rename(columns={'Type 2': 'Type_2', 'Type 1': 'Type_1'})
df.Type_2 = df.Type_2.fillna("poison")
df.head(5)
# Out:
#    #                   Name Type_1  Type_2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  poison  45      49       49       65
# 1  2                Ivysaur  Grass  poison  60      62       63       80
# 2  3               Venusaur  Grass  poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  poison  80     100      123      122
# 4  4             Charmander   Fier  poison  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  owner
# 0       65     45           1      False  abdur
# 1       80     60           1      False  abdur
# 2      100     80           1      False  abdur
# 3      120     80           1      False  abdur
# 4       50     65           1      False  abdur

# %% [markdown]
# # dublicates

# %%
## z = z.drop_duplicates(subset=None, keep='first', inplace=False)

# %% [markdown]
# # for print all row and columns

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns', None):
    print(df)
